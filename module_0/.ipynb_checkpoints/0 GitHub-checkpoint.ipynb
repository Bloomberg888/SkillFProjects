# %% [markdown]
# ## 2. Угадай число

# %%
import numpy as np

count = 0                           # счетчик попыток
number = np.random.randint(1,101)   # загадали число
print ("Загадано число от 1 до 100")
    
while True:                        # бесконечный цикл
    predict = int(input())         # предполагаемое число
    count += 1                     # плюсуем попытку
    if number == predict: break    # выход из цикла, если угадали
    elif number > predict: print (f"Угадываемое число больше {predict} ")
    elif number < predict: print (f"Угадываемое число меньше {predict} ")
        
print (f"Вы угадали число {number} за {count} попыток.")
# Out:
# Загадано число от 1 до 100
# 50
# Угадываемое число больше 50
# 75
# Угадываемое число меньше 75
# 62
# Угадываемое число больше 62
# 68
# Угадываемое число меньше 68
# 65
# Вы угадали число 65 за 5 попыток.

# %%
# number = np.random.randint(1,101)      # загадали число
print ("Загадано число от 1 до 100")
for count in range(1,101):         # более компактный вариант счетчика
    if number == count: break      # выход из цикла, если угадали      
print (f"Вы угадали число {number} за {count} попыток.")
# Out:
# Загадано число от 1 до 100
# Вы угадали число 57 за 57 попыток.

# %%
def game_core_v1(number):
    '''Просто угадываем на random, никак не используя информацию о больше или меньше.
       Функция принимает загаданное число и возвращает число попыток'''
    count = 0
    while True:
        count+=1
        predict = np.random.randint(1,101) # предполагаемое число
        if number == predict: 
            return count # выход из цикла, если угадали
        
        
def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

# %%
def game_core_v1(number):
    '''Просто угадываем на random, никак не используя информацию о больше или меньше.
       Функция принимает загаданное число и возвращает число попыток'''
    count = 0
    while True:
        count+=1
        predict = np.random.randint(1,101) # предполагаемое число
        if number == predict: 
            return count # выход из цикла, если угадали

# %%
# Out:
# Ваш алгоритм угадывает число в среднем за 101 попыток
# 101

# %%
def game_core_v2(number):
    '''Сначала устанавливаем любое random число, а потом уменьшаем или увеличиваем его в зависимости от того, больше оно или меньше нужного.
       Функция принимает загаданное число и возвращает число попыток'''
    count = 1
    predict = np.random.randint(1,101)
    #print(predict)
    while number != predict:
        count+=1
        if number > predict: 
            predict += 1
        elif number < predict: 
            predict -= 1
    return(count) # выход из цикла, если угадали

# %%
score_game(game_core_v2)
# Out:
# Ваш алгоритм угадывает число в среднем за 33 попыток
# 33

# %%
def game_core_my_version(number):
    '''
    '''
    count = 0
    first = 1
    last = 101
    predict = np.random.randint(start,end)
    while number != predict:
        count += 1
        if number > (start+end)//2:
            start = ((start+end)//2) + 1
        elif number < (start+end)//2:
            end = ((start+end)//2) - 1   
    return count

# %% [markdown]
# ## Итоговое задание:

# %%
def game_core_my_version(predict):
    '''Усредняем значения от и до, после чего уточняем, загаданное число больше или меньше усреднённого, 
    повторяем усреднение, с заменой значения "от" или "до" на усреднённое в зависимости от результата проверки'''
    count = 0
    #predict = np.random.randint(100)+1
    first = 1
    last = 100
    print('Загадано ',predict)
    while True:
        half=(first+last)//2
        count+=1
        if half == predict:
            print(f'Число {predict} отгадано за {count} попыток(-ки)')
            break
        elif predict > half: 
            first = half + 1
        elif predict < half: 
            last = half - 1
    return(count) # выход из цикла, если угадали

# %%
game_core_my_version(44)
# Out:
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# 6

# %%
score_game(game_core_my_version)
# Out:
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  7
# Число 7 отгадано за 6 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  48
# Число 48 отгадано за 6 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  81
# Число 81 отгадано за 4 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  7
# Число 7 отгадано за 6 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  7
# Число 7 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  60
# Число 60 отгадано за 6 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  48
# Число 48 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  36
# Число 36 отгадано за 7 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  48
# Число 48 отгадано за 6 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  48
# Число 48 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  36
# Число 36 отгадано за 7 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  81
# Число 81 отгадано за 4 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  60
# Число 60 отгадано за 6 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  74
# Число 74 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  36
# Число 36 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  81
# Число 81 отгадано за 4 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  7
# Число 7 отгадано за 6 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  36
# Число 36 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  5
# Число 5 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  60
# Число 60 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  5
# Число 5 отгадано за 7 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  81
# Число 81 отгадано за 4 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  91
# Число 91 отгадано за 5 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  80
# Число 80 отгадано за 7 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  94
# Число 94 отгадано за 4 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  18
# Число 18 отгадано за 4 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  5
# Число 5 отгадано за 7 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  68
# Число 68 отгадано за 4 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  25
# Число 25 отгадано за 2 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  36
# Число 36 отгадано за 7 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  7
# Число 7 отгадано за 6 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  30
# Число 30 отгадано за 7 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  59
# Число 59 отгадано за 5 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  35
# Число 35 отгадано за 6 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  5
# Число 5 отгадано за 7 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  91
# Число 91 отгадано за 5 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  29
# Число 29 отгадано за 6 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  67
# Число 67 отгадано за 7 попыток(-ки)
# Загадано  11
# Число 11 отгадано за 7 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  17
# Число 17 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  60
# Число 60 отгадано за 6 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  86
# Число 86 отгадано за 6 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  27
# Число 27 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  100
# Число 100 отгадано за 7 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  61
# Число 61 отгадано за 7 попыток(-ки)
# Загадано  71
# Число 71 отгадано за 5 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  91
# Число 91 отгадано за 5 попыток(-ки)
# Загадано  21
# Число 21 отгадано за 5 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  81
# Число 81 отгадано за 4 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  20
# Число 20 отгадано за 7 попыток(-ки)
# Загадано  95
# Число 95 отгадано за 6 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  48
# Число 48 отгадано за 6 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  39
# Число 39 отгадано за 7 попыток(-ки)
# Загадано  13
# Число 13 отгадано за 6 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  91
# Число 91 отгадано за 5 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  16
# Число 16 отгадано за 6 попыток(-ки)
# Загадано  38
# Число 38 отгадано за 6 попыток(-ки)
# Загадано  97
# Число 97 отгадано за 5 попыток(-ки)
# Загадано  37
# Число 37 отгадано за 3 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  8
# Число 8 отгадано за 7 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  51
# Число 51 отгадано за 6 попыток(-ки)
# Загадано  33
# Число 33 отгадано за 7 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  42
# Число 42 отгадано за 7 попыток(-ки)
# Загадано  70
# Число 70 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  31
# Число 31 отгадано за 4 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  82
# Число 82 отгадано за 6 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  45
# Число 45 отгадано за 7 попыток(-ки)
# Загадано  92
# Число 92 отгадано за 6 попыток(-ки)
# Загадано  10
# Число 10 отгадано за 6 попыток(-ки)
# Загадано  5
# Число 5 отгадано за 7 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  64
# Число 64 отгадано за 7 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  60
# Число 60 отгадано за 6 попыток(-ки)
# Загадано  65
# Число 65 отгадано за 5 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  32
# Число 32 отгадано за 6 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  85
# Число 85 отгадано за 7 попыток(-ки)
# Загадано  79
# Число 79 отгадано за 6 попыток(-ки)
# Загадано  69
# Число 69 отгадано за 6 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  26
# Число 26 отгадано за 6 попыток(-ки)
# Загадано  84
# Число 84 отгадано за 5 попыток(-ки)
# Загадано  28
# Число 28 отгадано за 5 попыток(-ки)
# Загадано  57
# Число 57 отгадано за 6 попыток(-ки)
# Загадано  93
# Число 93 отгадано за 7 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  56
# Число 56 отгадано за 4 попыток(-ки)
# Загадано  77
# Число 77 отгадано за 7 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  50
# Число 50 отгадано за 1 попыток(-ки)
# Загадано  12
# Число 12 отгадано за 3 попыток(-ки)
# Загадано  9
# Число 9 отгадано за 5 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  89
# Число 89 отгадано за 6 попыток(-ки)
# Загадано  90
# Число 90 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  83
# Число 83 отгадано за 7 попыток(-ки)
# Загадано  6
# Число 6 отгадано за 4 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  47
# Число 47 отгадано за 7 попыток(-ки)
# Загадано  22
# Число 22 отгадано за 7 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  74
# Число 74 отгадано за 7 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  14
# Число 14 отгадано за 7 попыток(-ки)
# Загадано  19
# Число 19 отгадано за 6 попыток(-ки)
# Загадано  24
# Число 24 отгадано за 7 попыток(-ки)
# Загадано  46
# Число 46 отгадано за 5 попыток(-ки)
# Загадано  96
# Число 96 отгадано за 7 попыток(-ки)
# Загадано  53
# Число 53 отгадано за 5 попыток(-ки)
# Загадано  34
# Число 34 отгадано за 5 попыток(-ки)
# Загадано  55
# Число 55 отгадано за 7 попыток(-ки)
# Загадано  15
# Число 15 отгадано за 5 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  62
# Число 62 отгадано за 3 попыток(-ки)
# Загадано  41
# Число 41 отгадано за 6 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  66
# Число 66 отгадано за 6 попыток(-ки)
# Загадано  23
# Число 23 отгадано за 6 попыток(-ки)
# Загадано  3
# Число 3 отгадано за 5 попыток(-ки)
# Загадано  87
# Число 87 отгадано за 7 попыток(-ки)
# Загадано  2
# Число 2 отгадано за 7 попыток(-ки)
# Загадано  73
# Число 73 отгадано за 6 попыток(-ки)
# Загадано  52
# Число 52 отгадано за 7 попыток(-ки)
# Загадано  72
# Число 72 отгадано за 7 попыток(-ки)
# Загадано  88
# Число 88 отгадано за 3 попыток(-ки)
# Загадано  78
# Число 78 отгадано за 5 попыток(-ки)
# Загадано  63
# Число 63 отгадано за 6 попыток(-ки)
# Загадано  49
# Число 49 отгадано за 7 попыток(-ки)
# Загадано  1
# Число 1 отгадано за 6 попыток(-ки)
# Загадано  43
# Число 43 отгадано за 4 попыток(-ки)
# Загадано  40
# Число 40 отгадано за 5 попыток(-ки)
# Загадано  4
# Число 4 отгадано за 6 попыток(-ки)
# Загадано  58
# Число 58 отгадано за 7 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  54
# Число 54 отгадано за 6 попыток(-ки)
# Загадано  44
# Число 44 отгадано за 6 попыток(-ки)
# Загадано  75
# Число 75 отгадано за 2 попыток(-ки)
# Загадано  99
# Число 99 отгадано за 6 попыток(-ки)
# Загадано  98
# Число 98 отгадано за 7 попыток(-ки)
# Загадано  76
# Число 76 отгадано за 6 попыток(-ки)
# Ваш алгоритм угадывает число в среднем за 5 попыток
# 5
